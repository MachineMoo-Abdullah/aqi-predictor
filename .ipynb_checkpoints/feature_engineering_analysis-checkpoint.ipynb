# %%
import pandas as pd

df = pd.read_csv("/Users/altair/Applications/aqi-predictor/Data_collection/data/raw/historical_dataset.csv")

# %%
print(df.head())
print(df.info())
print(df.describe())
print(df.shape)
# Out:
#          date  temperature_2m_max  temperature_2m_min  temperature_2m_mean  \
# 0  2024-01-01                18.3                 5.6                 11.3
# 1  2024-01-02                16.1                 6.4                 10.4
# 2  2024-01-03                16.0                 5.6                  9.3
# 3  2024-01-04                16.1                 5.7                 10.2
# 4  2024-01-05                16.1                 6.4                 10.3
#
#    precipitation_sum  wind_speed_10m_max      pm2_5       pm10  \
# 0                0.0                10.6  46.820833  70.829167
# 1                0.0                10.4  47.225000  70.975000
# 2                0.0                 6.0  59.083333  89.445833
# 3                0.0                 7.1  60.116667  93.029167
# 4                0.0                 7.3  63.808333  99.341667
#
#    carbon_monoxide  nitrogen_dioxide  sulphur_dioxide      ozone      us_aqi
# 0      1771.583333         59.891667        13.175000  31.958333  144.083333
# 1      1620.625000         61.275000        18.125000  30.833333  125.916667
# 2      1971.583333         64.070833        24.200000  34.625000  140.833333
# 3      1870.708333         66.083333        17.779167  32.625000  153.541667
# 4      2042.666667         66.600000        24.437500  39.208333  154.208333
# <class 'pandas.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 731 non-null    str
#  1   temperature_2m_max   731 non-null    float64
#  2   temperature_2m_min   731 non-null    float64
#  3   temperature_2m_mean  731 non-null    float64
#  4   precipitation_sum    731 non-null    float64
#  5   wind_speed_10m_max   731 non-null    float64
#  6   pm2_5                731 non-null    float64
#  7   pm10                 731 non-null    float64
#  8   carbon_monoxide      731 non-null    float64
#  9   nitrogen_dioxide     731 non-null    float64
#  10  sulphur_dioxide      731 non-null    float64
#  11  ozone                731 non-null    float64
#  12  us_aqi               731 non-null    float64
# dtypes: float64(12), str(1)
# memory usage: 74.4 KB
# None
#        temperature_2m_max  temperature_2m_min  temperature_2m_mean  \
# count          731.000000          731.000000           731.000000
# mean            27.421067           16.936115            21.743912
# std              7.279379            7.102744             7.317096
# min             11.300000            2.500000             8.400000
# 25%             20.900000           10.200000            14.800000
# 50%             28.500000           17.500000            22.700000
# 75%             32.700000           23.400000            27.800000
# max             44.300000           30.300000            37.000000
#
#        precipitation_sum  wind_speed_10m_max       pm2_5        pm10  \
# count         731.000000          731.000000  731.000000  731.000000
# mean            3.229138           12.801368   38.057410   53.717191
# std             8.268603            4.687579   16.644361   25.437882
# min             0.000000            3.600000   10.966667   15.616667
# 25%             0.000000            9.600000   25.681250   36.791667
# 50%             0.000000           11.900000   34.766667   47.925000
# 75%             1.600000           15.400000   46.868750   65.120833
# max            68.200000           35.200000  110.612500  238.537500
#
#        carbon_monoxide  nitrogen_dioxide  sulphur_dioxide       ozone  \
# count       731.000000        731.000000       731.000000  731.000000
# mean        952.344733         39.658881        11.598136   77.624202
# std         407.010688         14.619070         5.081966   27.306234
# min         278.791667          9.533333         3.662500   10.875000
# 25%         649.520833         27.970833         7.710417   57.208333
# 50%         896.833333         38.545833        10.600000   74.833333
# 75%        1156.125000         50.756250        13.931250   98.083333
# max        2427.333333         79.241667        31.212500  162.000000
#
#            us_aqi
# count  731.000000
# mean   112.124772
# std     27.738354
# min     61.541667
# 25%     89.583333
# 50%    106.458333
# 75%    133.250000
# max    184.208333
# (731, 13)

# %%
print(df.isnull().sum())
# Out:
# date                   0
# temperature_2m_max     0
# temperature_2m_min     0
# temperature_2m_mean    0
# precipitation_sum      0
# wind_speed_10m_max     0
# pm2_5                  0
# pm10                   0
# carbon_monoxide        0
# nitrogen_dioxide       0
# sulphur_dioxide        0
# ozone                  0
# us_aqi                 0
# dtype: int64

# %%
print(df.duplicated().sum())

df = df.drop_duplicates()
# Out:
# 0

# %%
print(df.dtypes)
# Out:
# date                       str
# temperature_2m_max     float64
# temperature_2m_min     float64
# temperature_2m_mean    float64
# precipitation_sum      float64
# wind_speed_10m_max     float64
# pm2_5                  float64
# pm10                   float64
# carbon_monoxide        float64
# nitrogen_dioxide       float64
# sulphur_dioxide        float64
# ozone                  float64
# us_aqi                 float64
# dtype: object

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
print(df.dtypes)
# Out:
# date                   datetime64[us]
# temperature_2m_max            float64
# temperature_2m_min            float64
# temperature_2m_mean           float64
# precipitation_sum             float64
# wind_speed_10m_max            float64
# pm2_5                         float64
# pm10                          float64
# carbon_monoxide               float64
# nitrogen_dioxide              float64
# sulphur_dioxide               float64
# ozone                         float64
# us_aqi                        float64
# dtype: object

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(18,12), bins=25)

plt.tight_layout()

plt.show()

# %% [markdown]
# ## **Analysis**
# ### Skewed Features. some are positive but are valid because there are some conditions in which values can be high based on the weather condition.
# ### in some features there are 2 peaks those are also valid because our data is of 2 years.

# %%
print(df.skew(numeric_only=True))
# Out:
# temperature_2m_max    -0.021111
# temperature_2m_min    -0.171437
# temperature_2m_mean   -0.096513
# precipitation_sum      3.743023
# wind_speed_10m_max     1.070218
# pm2_5                  1.019506
# pm10                   1.829032
# carbon_monoxide        0.982932
# nitrogen_dioxide       0.170561
# sulphur_dioxide        1.129208
# ozone                  0.225624
# us_aqi                 0.507072
# dtype: float64

# %%
for column in df.select_dtypes(include="number"):

    plt.figure(figsize=(6,3))

    sns.boxplot(x=df[column])

    plt.title(column)

    plt.show()

# %% [markdown]
# ## **Analysis**
# ### AQI naturally contains extreme pollution events, So no need to consider extreme values as outliers

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(12,10))

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.show()

# %% [markdown]
# ## **Analysis**
# ### We can combine temperature_2m_max,temperature_2m_min,temperature_2m_mean because they are highly correlated. But combining them or not depends on the modeel we are using to train

# %%
corr = df.corr(numeric_only=True)["us_aqi"]

print(corr.sort_values())
# Out:
# wind_speed_10m_max    -0.326191
# temperature_2m_max    -0.164895
# temperature_2m_mean   -0.155619
# temperature_2m_min    -0.133692
# precipitation_sum     -0.107533
# ozone                 -0.081328
# nitrogen_dioxide       0.450390
# carbon_monoxide        0.555944
# sulphur_dioxide        0.665658
# pm10                   0.725147
# pm2_5                  0.897067
# us_aqi                 1.000000
# Name: us_aqi, dtype: float64

# %%
for column in df.columns:

    if column not in ["us_aqi","date"]:

        plt.figure(figsize=(5,4))

        sns.scatterplot(
            data=df,
            x=column,
            y="us_aqi"
        )

        plt.show()

# %% [markdown]
# ## Analysis
# ### Only Pollutants have a linear relationship with AQI whereas weather featuree have weak relation or may be non linear relation which can be captured by deep learning or tree based models.

# %%
df["date"] = pd.to_datetime(df["date"])
df["month"] = df["date"].dt.month

monthly = (
    df.groupby("month")["us_aqi"]
      .mean()
      .reset_index()
)

import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(monthly["month"], monthly["us_aqi"], marker="o")
plt.xlabel("Month")
plt.ylabel("Average AQI")
plt.title("Average Monthly AQI")
plt.grid(True)
plt.show()

# %% [markdown]
# # Observations
# ## Winter (November–January)
# ### AQI is highest.
# ### This is common in many cities because:
# ### Cooler air can trap pollutants near the ground (temperature inversions).
# ### Lower wind speeds reduce dispersion.
# ### Additional emissions (heating, biomass burning, traffic) may contribute.
# ## Spring (March–April)
# ### AQI reaches its lowest levels.
# ### Likely due to better atmospheric mixing and fewer pollution episodes.
# ## Summer (June–July)
# ### AQI rises again.
# ### Hot weather and strong sunlight can increase ozone formation, and dry conditions can increase dust.
# ## Autumn (November)
# ### AQI increases sharply again, indicating a seasonal pollution pattern.

# %%
print(df[["date", "month", "us_aqi"]].head(20))
# Out:
#          date  month      us_aqi
# 0  2024-01-01      1  144.083333
# 1  2024-01-02      1  125.916667
# 2  2024-01-03      1  140.833333
# 3  2024-01-04      1  153.541667
# 4  2024-01-05      1  154.208333
# 5  2024-01-06      1  157.250000
# 6  2024-01-07      1  153.833333
# 7  2024-01-08      1  155.375000
# 8  2024-01-09      1  162.333333
# 9  2024-01-10      1  154.416667
# 10 2024-01-11      1  135.458333
# 11 2024-01-12      1  145.291667
# 12 2024-01-13      1  169.041667
# 13 2024-01-14      1  165.041667
# 14 2024-01-15      1  167.333333
# 15 2024-01-16      1  174.166667
# 16 2024-01-17      1  176.208333
# 17 2024-01-18      1  168.791667
# 18 2024-01-19      1  162.208333
# 19 2024-01-20      1  170.375000
