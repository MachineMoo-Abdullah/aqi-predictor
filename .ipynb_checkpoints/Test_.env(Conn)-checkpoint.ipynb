# %% [markdown]
# **Making .env File**

# %%
# %%writefile .env
# OPENWEATHER_API_KEY=4a3c8666d331e83d33dc4bbd0934828a
#
# LATITUDE=33.6844
# LONGITUDE=73.0479
#
# CITY=Rawalpindi
# COUNTRY=PK
#
# SUPABASE_HOST=aws-1-ap-northeast-2.pooler.supabase.com
# SUPABASE_PORT=6543
# SUPABASE_DB=postgres
# SUPABASE_USER=postgres.guzbjbyisvszoqncorlb
# SUPABASE_PASSWORD=pakchinA1.234
# Out:
# Overwriting .env

# %% [markdown]
# **Testing .env File**

# %%
from dotenv import load_dotenv
import os

load_dotenv()

print(os.getenv("OPENWEATHER_API_KEY"))
print(os.getenv("CITY"))
# Out:
# 4a3c8666d331e83d33dc4bbd0934828a
# Rawalpindi

# %%
with open(".env", "r") as f:
    print(f.read())
# Out:
# OPENWEATHER_API_KEY=4a3c8666d331e83d33dc4bbd0934828a
#
# LATITUDE=33.6844
# LONGITUDE=73.0479
#
# CITY=Rawalpindi
# COUNTRY=PK
#
# SUPABASE_HOST=aws-1-ap-northeast-2.pooler.supabase.com
# SUPABASE_PORT=6543
# SUPABASE_DB=postgres
# SUPABASE_USER=postgres.guzbjbyisvszoqncorlb
# SUPABASE_PASSWORD=pakchinA1.2
