# %%
from Feature_store_cloud.connection import engine

try:
    with engine.connect() as conn:
        result = conn.execute(
            "SELECT COUNT(*) FROM aqi_features"
        )
        print(result.fetchone())

    print("Database connected")

except Exception as e:
    print(e)
